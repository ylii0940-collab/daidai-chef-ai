# %%
import pandas as pd

# %%
df = pd.read_csv('state-areas.csv')

# %%
df
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
df = pd.read_csv('state-population.csv')#导入数据
print(df.population.mean())
print(df.population.std())
df =df.tail()
df.to_csv('new.csv')#导出数据
# Out:
# 6805558.401347068
# 28550144.966823243

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('weather_2012.sqlite')

tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)

df = pd.read_sql("SELECT * FROM weather_2012", conn)
df.head()
# Out:
#                                  name
# 0                     sqlite_sequence
# 1          ./data/weather_2012.sqlite
# 2   ./data/weather_2013_dancer.sqlite
# 3                       dacner_table1
# 4                       dancer_table1
# 5                        weather_2012
# 6                          1705_table
# 7                      1705_db.sqlite
# 8                          1706_score
# 9                          1706_table
# 10                        1706_table1
# 11                         1cer_table
# 12                             dancer
# 13                               bobo
# 14                               haha
# 15                         db_table_2
# 16                           sql_data
# 17                          sql_data1
#    index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0    0.0  2012-01-01 00:00:00      -1.8                -3.9         86.0
# 1    1.0  2012-01-01 01:00:00      -1.8                -3.7         87.0
# ...
